# %% [markdown]
# # Tools
#
# This notebook contains all the tools that will be used by the agent.

# %%
import requests
import sqlite3
import pandas as pd

from smolagents import tool, Tool

from langchain_community.tools.ddg_search.tool import DuckDuckGoSearchRun

# %% [markdown]
# ## Creating simple tool
#
# A Python function must be annotated with `@tool`. It should also have a docstring describing what does the function do, what does it return and the description of its parameters.

# %% [markdown]
# ### City to location
#
# The following function look up at latitude and longitude of a city.

# %%
# TODO: Load CSV file containing latitude, longitude and altitude of cities
# https://github.com/bahar/WorldCityLocations/tree/master
df = pd.read_csv('data/cities_latlng.csv', sep=';')
df.columns = [ 'id', 'country', 'city', 'latitude', 'longitude', 'altitude' ]

# %%
df.head()
# Out:
#    id      country            city   latitude  longitude  altitude
# 0   2  Afghanistan        Kandahar  31.610000  65.699997      1015
# 1   3  Afghanistan  Mazar-e Sharif  36.706944  67.112221       369
# 2   4  Afghanistan           Herat  34.340000  62.189999       927
# 3   5  Afghanistan       Jalalabad  34.420000  70.449997       573
# 4   6  Afghanistan          Konduz  36.720000  68.860001       394

# %%
# TODO: Explore the loaded dataframe
df[df['city'] == 'Singapore']
# Out:
#           id    country       city  latitude   longitude  altitude
# 10566  10568  Singapore  Singapore   1.29027  103.851959       164

# %%
# TODO: Add tool description

@tool
def get_latlng(city: str) -> any:
   """ 
   Give the latitude, longitude and altitude of a city

   Args:
      city: the name of the city that we want the altitude, longitude and latitude
      
   Returns:
      any: returns a dictionary with the followng keys: city, latitude, longitude and altitude

   Example:
      result = get_latlng('singapore')
   """
   r = df.query(f"city.str.lower() == '{city.lower()}'")
   return { 'city': city, 'latitude': float(r.iloc[0]['latitude']), 'longitude': float(r.iloc[0]['longitude']), 'altitude': float(r.iloc[0]['altitude']) }

# %%
# TODO: Test get_latlng method
# case insensitive search
get_latlng('tokyo')
# Out:
# {'city': 'tokyo',
#  'latitude': 35.6895266,
#  'longitude': 139.6916809,
#  'altitude': 40.0}

# %% [markdown]
# ### Temperature at latitude and longitude
#
# The following function lookup the weather at the given latitude and longtude.

# %%
# TODO: Add tool description
@tool
def get_temperature(latitude: float, longitude: float) -> any:
   """ 
   Return the temperature of a location given by its latitude and longitude

   Args:
      latitude: location's latitude
      longitude: location's longitude

   Return:
      any: a dictionary with the following keys: temperature_unit, temperature

   Example:
      result = get_temperature(35.689526, 139.6916809)
   """
   url = f"https://api.open-meteo.com/v1/forecast?latitude={latitude}&longitude={longitude}&current=temperature_2m"
   resp = requests.get(url)
   j = resp.json()
   if resp.status_code >= 400:
      raise Exception(j['reason'])
   temperature = j['current']['temperature_2m']
   units = j['current_units']['temperature_2m']
   return { "temperature_unit": units, "temperature": temperature }

# %%
# TODO: Test get_temperature method
get_temperature(35.689526, 139.6916809)
# Out:
# {'temperature_unit': '°C', 'temperature': 12.1}

# %%
# TODO: Create a web search tool

def web_search(query: str) -> any:

   search = DuckDuckGoSearchRun()
   return search.invoke(query)

# %%
# TODO: Test the web search

# %% [markdown]
# ### Query relational database
#
# The following function queries a relational database (SQLite) view called `album_track`. The table's schema is as follows:
# | Field name  | Type          |
# |-------------|---------------|
# | AlbumId     | integer       |
# | Title       | nvarchar(160) |
# | track_name  | nvarchar(200) |
# | artist_name | nvarchar(120) |
# | duration    | integer       |
# | composer    | nvarchar(220) |

# %%
# TODO: Add tool description
@tool
def query_album_track(query: str) -> any:
   """ 
   Perform SQL query on the album_track table. Returns the result as an array of tuples. 
   The table name is album_track; the table has the following columns:
      AlbumId: integer
      Title: nvarchar(160)
      track_name: nvarchar(200)
      artist_name: nvarchar(120)
      duration: integer
      composer: nvarchar(220)
   The duration is in milliseconds

   Args:
      query: a valid SQL Sqlite query

   Return:
      any: list of tuple. Each element of the tuple corresponds to a record return by the query

   Example:
      results = query_album_track('select * from album_track"')
   """
   database = "data/chinook_sqlite.sqlite" 
   conn = sqlite3.connect(database)
   try:
      cursor = conn.cursor() 
      rows = cursor.execute(query)
      return rows.fetchall()
   finally:
      conn.close()

# %%
# TODO: Test the query_album_track function
query_album_track('select * from album_track where artist_name like "%AC%" ')
# Out:
# [(1,
#   'For Those About To Rock We Salute You',
#   'For Those About To Rock (We Salute You)',
#   'AC/DC',
#   343719,
#   'Angus Young, Malcolm Young, Brian Johnson'),
#  (2, 'Balls to the Wall', 'Balls to the Wall', 'Accept', 342562, None),
#  (3,
#   'Restless and Wild',
#   'Fast As a Shark',
#   'Accept',
#   230619,
#   'F. Baltes, S. Kaufman, U. Dirkscneider & W. Hoffman'),
#  (3,
#   'Restless and Wild',
#   'Restless and Wild',
#   'Accept',
#   252051,
#   'F. Baltes, R.A. Smith-Diesel, S. Kaufman, U. Dirkscneider & W. Hoffman'),
#  (3,
#   'Restless and Wild',
#   'Princess of the Dawn',
#   'Accept',
#   375418,
#   'Deaffy & R.A. Smith-Diesel'),
#  (1,
#   'For Those About To Rock We Salute You',
#   'Put The Finger On You',
#   'AC/DC',
#   205662,
#   'Angus Young, Malcolm Young, Brian Johnson'),
#  (1,
#   'For Those About To Rock We Salute You',
#   "Let's Get It Up",
#   'AC/DC',
#   233926,
#   'Angus Young, Malcolm Young, Brian Johnson'),
#  (1,
#   'For Those About To Rock We Salute You',
#   'Inject The Venom',
#   'AC/DC',
#   210834,
#   'Angus Young, Malcolm Young, Brian Johnson'),
#  (1,
#   'For Those About To Rock We Salute You',
#   'Snowballed',
#   'AC/DC',
#   203102,
#   'Angus Young, Malcolm Young, Brian Johnson'),
#  (1,
#   'For Those About To Rock We Salute You',
#   'Evil Walks',
#   'AC/DC',
#   263497,
#   'Angus Young, Malcolm Young, Brian Johnson'),
#  (1,
#   'For Those About To Rock We Salute You',
#   'C.O.D.',
#   'AC/DC',
#   199836,
#   'Angus Young, Malcolm Young, Brian Johnson'),
#  (1,
#   'For Those About To Rock We Salute You',
#   'Breaking The Rules',
#   'AC/DC',
#   263288,
#   'Angus Young, Malcolm Young, Brian Johnson'),
#  (1,
#   'For Those About To Rock We Salute You',
#   'Night Of The Long Knives',
#   'AC/DC',
#   205688,
#   'Angus Young, Malcolm Young, Brian Johnson'),
#  (1,
#   'For Those About To Rock We Salute You',
#   'Spellbound',
#   'AC/DC',
#   270863,
#   'Angus Young, Malcolm Young, Brian Johnson'),
#  (4, 'Let There Be Rock', 'Go Down', 'AC/DC', 331180, 'AC/DC'),
#  (4, 'Let There Be Rock', 'Dog Eat Dog', 'AC/DC', 215196, 'AC/DC'),
#  (4, 'Let There Be Rock', 'Let There Be Rock', 'AC/DC', 366654, 'AC/DC'),
#  (4, 'Let There Be Rock', 'Bad Boy Boogie', 'AC/DC', 267728, 'AC/DC'),
#  (4, 'Let There Be Rock', 'Problem Child', 'AC/DC', 325041, 'AC/DC'),
#  (4, 'Let There Be Rock', 'Overdose', 'AC/DC', 369319, 'AC/DC'),
#  (4,
#   'Let There Be Rock',
#   "Hell Ain't A Bad Place To Be",
#   'AC/DC',
#   254380,
#   'AC/DC'),
#  (4, 'Let There Be Rock', 'Whole Lotta Rosie', 'AC/DC', 323761, 'AC/DC'),
#  (12,
#   'BackBeat Soundtrack',
#   'Money',
#   'BackBeat',
#   147591,
#   'Berry Gordy, Jr./Janie Bradford'),
#  (12,
#   'BackBeat Soundtrack',
#   'Long Tall Sally',
#   'BackBeat',
#   106396,
#   'Enotris Johnson/Little Richard/Robert "Bumps" Blackwell'),
#  (12, 'BackBeat Soundtrack', 'Bad Boy', 'BackBeat', 116088, 'Larry Williams'),
#  (12,
#   'BackBeat Soundtrack',
#   'Twist And Shout',
#   'BackBeat',
#   161123,
#   'Bert Russell/Phil Medley'),
#  (12,
#   'BackBeat Soundtrack',
#   'Please Mr. Postman',
#   'BackBeat',
#   137639,
#   'Brian Holland/Freddie Gorman/Georgia Dobbins/Robert Bateman/William Garrett'),
#  (12,
#   'BackBeat Soundtrack',
#   "C'Mon Everybody",
#   'BackBeat',
#   140199,
#   'Eddie Cochran/Jerry Capehart'),
#  (12,
#   'BackBeat Soundtrack',
#   "Rock 'N' Roll Music",
#   'BackBeat',
#   141923,
#   'Chuck Berry'),
#  (12,
#   'BackBeat Soundtrack',
#   'Slow Down',
#   'BackBeat',
#   163265,
#   'Larry Williams'),
#  (12, 'BackBeat Soundtrack', 'Roadrunner', 'BackBeat', 143595, 'Bo Diddley'),
#  (12, 'BackBeat Soundtrack', 'Carol', 'BackBeat', 143830, 'Chuck Berry'),
#  (12,
#   'BackBeat Soundtrack',
#   'Good Golly Miss Molly',
#   'BackBeat',
#   106266,
#   'Little Richard'),
#  (12,
#   'BackBeat Soundtrack',
#   '20 Flight Rock',
#   'BackBeat',
#   107807,
#   'Ned Fairchild'),
#  (14,
#   'Alcohol Fueled Brewtality Live! [Disc 1]',
#   'Intro/ Low Down',
#   'Black Label Society',
#   323683,
#   None),
#  (14,
#   'Alcohol Fueled Brewtality Live! [Disc 1]',
#   '13 Years Of Grief',
#   'Black Label Society',
#   246987,
#   None),
#  (14,
#   'Alcohol Fueled Brewtality Live! [Disc 1]',
#   'Stronger Than Death',
#   'Black Label Society',
#   300747,
#   None),
#  (14,
#   'Alcohol Fueled Brewtality Live! [Disc 1]',
#   'All For You',
#   'Black Label Society',
#   235833,
#   None),
#  (14,
#   'Alcohol Fueled Brewtality Live! [Disc 1]',
#   'Super Terrorizer',
#   'Black Label Society',
#   319373,
#   None),
#  (14,
#   'Alcohol Fueled Brewtality Live! [Disc 1]',
#   'Phoney Smile Fake Hellos',
#   'Black Label Society',
#   273606,
#   None),
#  (14,
#   'Alcohol Fueled Brewtality Live! [Disc 1]',
#   'Lost My Better Half',
#   'Black Label Society',
#   284081,
#   None),
#  (14,
#   'Alcohol Fueled Brewtality Live! [Disc 1]',
#   'Bored To Tears',
#   'Black Label Society',
#   247327,
#   None),
#  (14,
#   'Alcohol Fueled Brewtality Live! [Disc 1]',
#   'A.N.D.R.O.T.A.Z.',
#   'Black Label Society',
#   266266,
#   None),
#  (14,
#   'Alcohol Fueled Brewtality Live! [Disc 1]',
#   'Born To Booze',
#   'Black Label Society',
#   282122,
#   None),
#  (14,
#   'Alcohol Fueled Brewtality Live! [Disc 1]',
#   'World Of Trouble',
#   'Black Label Society',
#   359157,
#   None),
#  (14,
#   'Alcohol Fueled Brewtality Live! [Disc 1]',
#   'No More Tears',
#   'Black Label Society',
#   555075,
#   None),
#  (14,
#   'Alcohol Fueled Brewtality Live! [Disc 1]',
#   'The Begining... At Last',
#   'Black Label Society',
#   365662,
#   None),
#  (15,
#   'Alcohol Fueled Brewtality Live! [Disc 2]',
#   'Heart Of Gold',
#   'Black Label Society',
#   194873,
#   None),
#  (15,
#   'Alcohol Fueled Brewtality Live! [Disc 2]',
#   'Snowblind',
#   'Black Label Society',
#   420022,
#   None),
#  (15,
#   'Alcohol Fueled Brewtality Live! [Disc 2]',
#   'Like A Bird',
#   'Black Label Society',
#   276532,
#   None),
#  (15,
#   'Alcohol Fueled Brewtality Live! [Disc 2]',
#   'Blood In The Wall',
#   'Black Label Society',
#   284368,
#   None),
#  (15,
#   'Alcohol Fueled Brewtality Live! [Disc 2]',
#   'The Beginning...At Last',
#   'Black Label Society',
#   271960,
#   None),
#  (16, 'Black Sabbath', 'Black Sabbath', 'Black Sabbath', 382066, None),
#  (16, 'Black Sabbath', 'The Wizard', 'Black Sabbath', 264829, None),
#  (16,
#   'Black Sabbath',
#   'Behind The Wall Of Sleep',
#   'Black Sabbath',
#   217573,
#   None),
#  (16, 'Black Sabbath', 'N.I.B.', 'Black Sabbath', 368770, None),
#  (16, 'Black Sabbath', 'Evil Woman', 'Black Sabbath', 204930, None),
#  (16, 'Black Sabbath', 'Sleeping Village', 'Black Sabbath', 644571, None),
#  (16, 'Black Sabbath', 'Warning', 'Black Sabbath', 212062, None),
#  (17,
#   'Black Sabbath Vol. 4 (Remaster)',
#   'Wheels Of Confusion / The Straightener',
#   'Black Sabbath',
#   494524,
#   'Tony Iommi, Bill Ward, Geezer Butler, Ozzy Osbourne'),
#  (17,
#   'Black Sabbath Vol. 4 (Remaster)',
#   "Tomorrow's Dream",
#   'Black Sabbath',
#   192496,
#   'Tony Iommi, Bill Ward, Geezer Butler, Ozzy Osbourne'),
#  (17,
#   'Black Sabbath Vol. 4 (Remaster)',
#   'Changes',
#   'Black Sabbath',
#   286275,
#   'Tony Iommi, Bill Ward, Geezer Butler, Ozzy Osbourne'),
#  (17,
#   'Black Sabbath Vol. 4 (Remaster)',
#   'FX',
#   'Black Sabbath',
#   103157,
#   'Tony Iommi, Bill Ward, Geezer Butler, Ozzy Osbourne'),
#  (17,
#   'Black Sabbath Vol. 4 (Remaster)',
#   'Supernaut',
#   'Black Sabbath',
#   285779,
#   'Tony Iommi, Bill Ward, Geezer Butler, Ozzy Osbourne'),
#  (17,
#   'Black Sabbath Vol. 4 (Remaster)',
#   'Snowblind',
#   'Black Sabbath',
#   331676,
#   'Tony Iommi, Bill Ward, Geezer Butler, Ozzy Osbourne'),
#  (17,
#   'Black Sabbath Vol. 4 (Remaster)',
#   'Cornucopia',
#   'Black Sabbath',
#   234814,
#   'Tony Iommi, Bill Ward, Geezer Butler, Ozzy Osbourne'),
#  (17,
#   'Black Sabbath Vol. 4 (Remaster)',
#   'Laguna Sunrise',
#   'Black Sabbath',
#   173087,
#   'Tony Iommi, Bill Ward, Geezer Butler, Ozzy Osbourne'),
#  (17,
#   'Black Sabbath Vol. 4 (Remaster)',
#   'St. Vitus Dance',
#   'Black Sabbath',
#   149655,
#   'Tony Iommi, Bill Ward, Geezer Butler, Ozzy Osbourne'),
#  (17,
#   'Black Sabbath Vol. 4 (Remaster)',
#   'Under The Sun/Every Day Comes and Goes',
#   'Black Sabbath',
#   350458,
#   'Tony Iommi, Bill Ward, Geezer Butler, Ozzy Osbourne'),
#  (88, 'Faceless', 'Straight Out Of Line', 'Godsmack', 259213, 'Sully Erna'),
#  (88, 'Faceless', 'Faceless', 'Godsmack', 216006, 'Sully Erna'),
#  (88, 'Faceless', 'Changes', 'Godsmack', 260022, 'Sully Erna; Tony Rombola'),
#  (88, 'Faceless', 'Make Me Believe', 'Godsmack', 248607, 'Sully Erna'),
#  (88, 'Faceless', 'I Stand Alone', 'Godsmack', 246125, 'Sully Erna'),
#  (88, 'Faceless', 'Re-Align', 'Godsmack', 260884, 'Sully Erna'),
#  (88, 'Faceless', 'I Fucking Hate You', 'Godsmack', 247170, 'Sully Erna'),
#  (88, 'Faceless', 'Releasing The Demons', 'Godsmack', 252760, 'Sully Erna'),
#  (88, 'Faceless', 'Dead And Broken', 'Godsmack', 251454, 'Sully Erna'),
#  (88, 'Faceless', 'I Am', 'Godsmack', 239516, 'Sully Erna'),
#  (88, 'Faceless', 'The Awakening', 'Godsmack', 89547, 'Sully Erna'),
#  (88, 'Faceless', 'Serenity', 'Godsmack', 274834, 'Sully Erna; Tony Rombola'),
#  (209,
#   'Live [Disc 1]',
#   'Midnight From The Inside Out',
#   'The Black Crowes',
#   286981,
#   'Chris Robinson/Rich Robinson'),
#  (209,
#   'Live [Disc 1]',
#   'Sting Me',
#   'The Black Crowes',
#   268094,
#   'Chris Robinson/Rich Robinson'),
#  (209,
#   'Live [Disc 1]',
#   'Thick & Thin',
#   'The Black Crowes',
#   222720,
#   'Chris Robinson/Rich Robinson'),
#  (209,
#   'Live [Disc 1]',
#   'Greasy Grass River',
#   'The Black Crowes',
#   218749,
#   'Chris Robinson/Rich Robinson'),
#  (209,
#   'Live [Disc 1]',
#   'Sometimes Salvation',
#   'The Black Crowes',
#   389146,
#   'Chris Robinson/Rich Robinson'),
#  (209,
#   'Live [Disc 1]',
#   'Cursed Diamonds',
#   'The Black Crowes',
#   368300,
#   'Chris Robinson/Rich Robinson'),
#  (209,
#   'Live [Disc 1]',
#   'Miracle To Me',
#   'The Black Crowes',
#   372636,
#   'Chris Robinson/Rich Robinson'),
#  (209,
#   'Live [Disc 1]',
#   'Wiser Time',
#   'The Black Crowes',
#   459990,
#   'Chris Robinson/Rich Robinson'),
#  (209,
#   'Live [Disc 1]',
#   'Girl From A Pawnshop',
#   'The Black Crowes',
#   404688,
#   'Chris Robinson/Rich Robinson'),
#  (209,
#   'Live [Disc 1]',
#   'Cosmic Fiend',
#   'The Black Crowes',
#   308401,
#   'Chris Robinson/Rich Robinson'),
#  (210,
#   'Live [Disc 2]',
#   'Black Moon Creeping',
#   'The Black Crowes',
#   359314,
#   'Chris Robinson/Rich Robinson'),
#  (210,
#   'Live [Disc 2]',
#   'High Head Blues',
#   'The Black Crowes',
#   371879,
#   'Chris Robinson/Rich Robinson'),
#  (210,
#   'Live [Disc 2]',
#   'Title Song',
#   'The Black Crowes',
#   505521,
#   'Chris Robinson/Rich Robinson'),
#  (210,
#   'Live [Disc 2]',
#   'She Talks To Angels',
#   'The Black Crowes',
#   361978,
#   'Chris Robinson/Rich Robinson'),
#  (210,
#   'Live [Disc 2]',
#   'Twice As Hard',
#   'The Black Crowes',
#   275565,
#   'Chris Robinson/Rich Robinson'),
#  (210,
#   'Live [Disc 2]',
#   "Lickin'",
#   'The Black Crowes',
#   314409,
#   'Chris Robinson/Rich Robinson'),
#  (210,
#   'Live [Disc 2]',
#   'Soul Singing',
#   'The Black Crowes',
#   233639,
#   'Chris Robinson/Rich Robinson'),
#  (210,
#   'Live [Disc 2]',
#   'Hard To Handle',
#   'The Black Crowes',
#   206994,
#   'A.Isbell/A.Jones/O.Redding'),
#  (210,
#   'Live [Disc 2]',
#   'Remedy',
#   'The Black Crowes',
#   337084,
#   'Chris Robinson/Rich Robinson'),
#  (226,
#   'Battlestar Galactica: The Story So Far',
#   'Battlestar Galactica: The Story So Far',
#   'Battlestar Galactica',
#   2622250,
#   None),
#  (227,
#   'Battlestar Galactica, Season 3',
#   'Occupation / Precipice',
#   'Battlestar Galactica',
#   5286953,
#   None),
#  (227,
#   'Battlestar Galactica, Season 3',
#   'Exodus, Pt. 1',
#   'Battlestar Galactica',
#   2621708,
#   None),
#  (227,
#   'Battlestar Galactica, Season 3',
#   'Exodus, Pt. 2',
#   'Battlestar Galactica',
#   2618000,
#   None),
#  (227,
#   'Battlestar Galactica, Season 3',
#   'Collaborators',
#   'Battlestar Galactica',
#   2626626,
#   None),
#  (227,
#   'Battlestar Galactica, Season 3',
#   'Torn',
#   'Battlestar Galactica',
#   2631291,
#   None),
#  (227,
#   'Battlestar Galactica, Season 3',
#   'A Measure of Salvation',
#   'Battlestar Galactica',
#   2563938,
#   None),
#  (227,
#   'Battlestar Galactica, Season 3',
#   'Hero',
#   'Battlestar Galactica',
#   2713755,
#   None),
#  (227,
#   'Battlestar Galactica, Season 3',
#   'Unfinished Business',
#   'Battlestar Galactica',
#   2622038,
#   None),
#  (227,
#   'Battlestar Galactica, Season 3',
#   'The Passage',
#   'Battlestar Galactica',
#   2623875,
#   None),
#  (227,
#   'Battlestar Galactica, Season 3',
#   'The Eye of Jupiter',
#   'Battlestar Galactica',
#   2618750,
#   None),
#  (227,
#   'Battlestar Galactica, Season 3',
#   'Rapture',
#   'Battlestar Galactica',
#   2624541,
#   None),
#  (227,
#   'Battlestar Galactica, Season 3',
#   'Taking a Break from All Your Worries',
#   'Battlestar Galactica',
#   2624207,
#   None),
#  (227,
#   'Battlestar Galactica, Season 3',
#   'The Woman King',
#   'Battlestar Galactica',
#   2626376,
#   None),
#  (227,
#   'Battlestar Galactica, Season 3',
#   'A Day In the Life',
#   'Battlestar Galactica',
#   2620245,
#   None),
#  (227,
#   'Battlestar Galactica, Season 3',
#   'Dirty Hands',
#   'Battlestar Galactica',
#   2627961,
#   None),
#  (227,
#   'Battlestar Galactica, Season 3',
#   'Maelstrom',
#   'Battlestar Galactica',
#   2622372,
#   None),
#  (227,
#   'Battlestar Galactica, Season 3',
#   'The Son Also Rises',
#   'Battlestar Galactica',
#   2621830,
#   None),
#  (227,
#   'Battlestar Galactica, Season 3',
#   'Crossroads, Pt. 1',
#   'Battlestar Galactica',
#   2622622,
#   None),
#  (227,
#   'Battlestar Galactica, Season 3',
#   'Crossroads, Pt. 2',
#   'Battlestar Galactica',
#   2869953,
#   None),
#  (253,
#   'Battlestar Galactica (Classic), Season 1',
#   'Battlestar Galactica, Pt. 1',
#   'Battlestar Galactica (Classic)',
#   2952702,
#   None),
#  (253,
#   'Battlestar Galactica (Classic), Season 1',
#   'Battlestar Galactica, Pt. 2',
#   'Battlestar Galactica (Classic)',
#   2956081,
#   None),
#  (253,
#   'Battlestar Galactica (Classic), Season 1',
#   'Battlestar Galactica, Pt. 3',
#   'Battlestar Galactica (Classic)',
#   2927802,
#   None),
#  (253,
#   'Battlestar Galactica (Classic), Season 1',
#   'Lost Planet of the Gods, Pt. 1',
#   'Battlestar Galactica (Classic)',
#   2922547,
#   None),
#  (253,
#   'Battlestar Galactica (Classic), Season 1',
#   'Lost Planet of the Gods, Pt. 2',
#   'Battlestar Galactica (Classic)',
#   2914664,
#   None),
#  (253,
#   'Battlestar Galactica (Classic), Season 1',
#   'The Lost Warrior',
#   'Battlestar Galactica (Classic)',
#   2920045,
#   None),
#  (253,
#   'Battlestar Galactica (Classic), Season 1',
#   'The Long Patrol',
#   'Battlestar Galactica (Classic)',
#   2925008,
#   None),
#  (253,
#   'Battlestar Galactica (Classic), Season 1',
#   'The Gun On Ice Planet Zero, Pt. 1',
#   'Battlestar Galactica (Classic)',
#   2907615,
#   None),
#  (253,
#   'Battlestar Galactica (Classic), Season 1',
#   'The Gun On Ice Planet Zero, Pt. 2',
#   'Battlestar Galactica (Classic)',
#   2924341,
#   None),
#  (253,
#   'Battlestar Galactica (Classic), Season 1',
#   'The Magnificent Warriors',
#   'Battlestar Galactica (Classic)',
#   2924716,
#   None),
#  (253,
#   'Battlestar Galactica (Classic), Season 1',
#   'The Young Lords',
#   'Battlestar Galactica (Classic)',
#   2863571,
#   None),
#  (253,
#   'Battlestar Galactica (Classic), Season 1',
#   'The Living Legend, Pt. 1',
#   'Battlestar Galactica (Classic)',
#   2924507,
#   None),
#  (253,
#   'Battlestar Galactica (Classic), Season 1',
#   'The Living Legend, Pt. 2',
#   'Battlestar Galactica (Classic)',
#   2923298,
#   None),
#  (253,
#   'Battlestar Galactica (Classic), Season 1',
#   'Fire In Space',
#   'Battlestar Galactica (Classic)',
#   2926593,
#   None),
#  (253,
#   'Battlestar Galactica (Classic), Season 1',
#   'War of the Gods, Pt. 1',
#   'Battlestar Galactica (Classic)',
#   2922630,
#   None),
#  (253,
#   'Battlestar Galactica (Classic), Season 1',
#   'War of the Gods, Pt. 2',
#   'Battlestar Galactica (Classic)',
#   2923381,
#   None),
#  (253,
#   'Battlestar Galactica (Classic), Season 1',
#   'The Man With Nine Lives',
#   'Battlestar Galactica (Classic)',
#   2956998,
#   None),
#  (253,
#   'Battlestar Galactica (Classic), Season 1',
#   'Murder On the Rising Star',
#   'Battlestar Galactica (Classic)',
#   2935894,
#   None),
#  (253,
#   'Battlestar Galactica (Classic), Season 1',
#   'Greetings from Earth, Pt. 1',
#   'Battlestar Galactica (Classic)',
#   2960293,
#   None),
#  (253,
#   'Battlestar Galactica (Classic), Season 1',
#   'Greetings from Earth, Pt. 2',
#   'Battlestar Galactica (Classic)',
#   2903778,
#   None),
#  (253,
#   'Battlestar Galactica (Classic), Season 1',
#   "Baltar's Escape",
#   'Battlestar Galactica (Classic)',
#   2922088,
#   None),
#  (253,
#   'Battlestar Galactica (Classic), Season 1',
#   'Experiment In Terra',
#   'Battlestar Galactica (Classic)',
#   2923548,
#   None),
#  (253,
#   'Battlestar Galactica (Classic), Season 1',
#   'Take the Celestra',
#   'Battlestar Galactica (Classic)',
#   2927677,
#   None),
#  (253,
#   'Battlestar Galactica (Classic), Season 1',
#   'The Hand of God',
#   'Battlestar Galactica (Classic)',
#   2924007,
#   None),
#  (280,
#   'The World of Classical Favourites',
#   'Solomon HWV 67: The Arrival of the Queen of Sheba',
#   'Academy of St. Martin in the Fields & Sir Neville Marriner',
#   197135,
#   'George Frideric Handel'),
#  (281,
#   'Sir Neville Marriner: A Celebration',
#   '"Eine Kleine Nachtmusik" Serenade In G, K. 525: I. Allegro',
#   'Academy of St. Martin in the Fields Chamber Ensemble & Sir Neville Marriner',
#   348971,
#   'Wolfgang Amadeus Mozart'),
#  (288,
#   'Fauré: Requiem, Ravel: Pavane & Others',
#   'Requiem, Op.48: 4. Pie Jesu',
#   'Academy of St. Martin in the Fields, John Birch, Sir Neville Marriner & Sylvia McNair',
#   258924,
#   'Gabriel Fauré'),
#  (289,
#   'Tchaikovsky: The Nutcracker',
#   'The Nutcracker, Op. 71a, Act II: Scene 14: Pas de deux: Dance of the Prince & the Sugar-Plum Fairy',
#   'London Symphony Orchestra & Sir Charles Mackerras',
#   304226,
#   'Peter Ilyich Tchaikovsky'),
#  (280,
#   'The World of Classical Favourites',
#   'Fantasia On Greensleeves',
#   'Academy of St. Martin in the Fields & Sir Neville Marriner',
#   268066,
#   'Ralph Vaughan Williams'),
#  (327,
#   'Bach: Orchestral Suites Nos. 1 - 4',
#   'Suite No. 3 in D, BWV 1068: III. Gavotte I & II',
#   'Academy of St. Martin in the Fields, Sir Neville Marriner & Thurston Dart',
#   225933,
#   'Johann Sebastian Bach'),
#  (345,
#   "Monteverdi: L'Orfeo",
#   "L'orfeo, Act 3, Sinfonia (Orchestra)",
#   'C. Monteverdi, Nigel Rogers - Chiaroscuro; London Baroque; London Cornett & Sackbu',
#   66639,
#   'Claudio Monteverdi')]

# %% [markdown]
# ### Tools with states
#
# The following isn an example of a more complex tool that requires initialisation

# %%
class SQLiteTool(Tool):
   # give the tool a name
   name = "music_database"

   description = """ 
   Perform SQL query on the album_track table. Returns the result as an array of tuples. 
   The table name is album_track; the table has the following columns:
      AlbumId: integer
      Title: nvarchar(160)
      track_name: nvarchar(200)
      artist_name: nvarchar(120)
      duration: integer
      composer: nvarchar(220)
   The duration is in milliseconds
   """

   inputs = {
      "query": {
         "type": "string",
         "description": "a valid SQL Sqlite query"
      },
   }

   output_type = "any"

   def __init__(self, db_file):
      self.db_file = db_file 
      self.setup()

   def setup(self):
      super().setup()
      self.conn = sqlite3.connect(self.db_file)

   def forward(self, query: str) -> any:
      try:
         cursor = self.conn.cursor() 
         rows = cursor.execute(query)
         return rows.fetchall()
      except Exception as e:
         print(f'Query exception: {e}')
